# %%
import pandas as pd
import numpy as np

# %%
f = pd.read_csv("../../data/aetna_piecewise/california_0.csv")

# %%
f
# Out:
#        Unnamed: 0 negotiation_arrangement                          name  \
# 0               0                     ffs  Part Hosp Intensive Servic..
# 1               0                     ffs  Part Hosp Intensive Servic..
# 2               0                     ffs  Part Hosp Intensive Servic..
# 3               0                     ffs  Part Hosp Intensive Servic..
# 4               0                     ffs  Part Hosp Intensive Servic..
# ...           ...                     ...                           ...
# 10577           0                     ffs   130/REV AND 10D07Z6/ICD10PX
# 10578           0                     ffs   130/REV AND 10D07Z6/ICD10PX
# 10579           0                     ffs   130/REV AND 10D07Z6/ICD10PX
# 10580           0                     ffs   130/REV AND 10D07Z6/ICD10PX
# 10581           0                     ffs   130/REV AND 10D07Z6/ICD10PX
#
#       billing_code_type  billing_code_type_version billing_code  \
# ...

# %%
//
